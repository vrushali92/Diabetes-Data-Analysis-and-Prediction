# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data/diabetes_clean.csv")
data
# Out:
#        gender  age hypertension heart_disease smoking_history  bmi_score  \
# 0      Female   80           No           Yes           never      25.19
# 1      Female   54           No            No         no info      27.32
# 2        Male   28           No            No           never      27.32
# 3      Female   36           No            No         current      23.45
# 4        Male   76          Yes           Yes         current      20.14
# ...       ...  ...          ...           ...             ...        ...
# 99995  Female   80           No            No         no info      27.32
# 99996  Female    2           No            No         no info      17.37
# 99997    Male   66           No            No          former      27.83
# 99998  Female   24           No            No           never      35.42
# 99999  Female   57           No            No         current      22.43
#
#        haemoglobin_level  blood_glucose_level  is_diabetic
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
sns.countplot(data = data, x = "gender")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data = data, x = "hypertension", hue = "is_diabetic")
# Out:
# <Axes: xlabel='hypertension', ylabel='count'>

# %%
sns.countplot(data = data, x = "heart_disease", hue = "is_diabetic")
# Out:
# <Axes: xlabel='heart_disease', ylabel='count'>

# %%
sns.countplot(data = data, x = "smoking_history", hue = "is_diabetic")
# Out:
# <Axes: xlabel='smoking_history', ylabel='count'>

# %%
sns.countplot(data = data, x = "is_diabetic")
# Out:
# <Axes: xlabel='is_diabetic', ylabel='count'>

# %%
sns.boxplot(data = data, x = "age")
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# 💡Insight: There are no outliers in age column.

# %%
sns.histplot(data = data, x = "age", hue = "is_diabetic")
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# 💡 Insight: Age is most important factor in causing diabetes. People of age 80 have highest number of diabetes.

# %%
sns.boxplot(data = data, x = "bmi_score")
# Out:
# <Axes: xlabel='bmi_score'>

# %% [markdown]
# 💡Insight: There are some outliers in bmi_score having values beyond 70.

# %%
sns.boxplot(data = data, x = "haemoglobin_level")
# Out:
# <Axes: xlabel='haemoglobin_level'>

# %% [markdown]
# 💡Insight: There are 2 outliers in haemoglobin_level having values 8.9, 9.

# %%
sns.displot(data = data, x = "haemoglobin_level", hue = "is_diabetic")

# %% [markdown]
# 💡Insight: Looks like people have HbA1c_level between 6.5 and 9 have high chances of getting diabetes.

# %%
sns.boxplot(data = data, x = "blood_glucose_level")
# Out:
# <Axes: xlabel='blood_glucose_level'>

# %% [markdown]
# 💡Insight: There are 3 outliers in blood_glucose_level having values between 250 and 300.

# %%
sns.displot(data = data, x = "blood_glucose_level", hue = "is_diabetic")

# %% [markdown]
# 💡Insight: People who have blood_glucose_level between 225 and 300 definitely have diabetes.
#     And there are also people who got diabetes having blood_glucose_level between 125 and 200.

# %%
data.head()
# Out:
#    gender  age hypertension heart_disease smoking_history  bmi_score  \
# 0  Female   80           No           Yes           never      25.19
# 1  Female   54           No            No         no info      27.32
# 2    Male   28           No            No           never      27.32
# 3  Female   36           No            No         current      23.45
# 4    Male   76          Yes           Yes         current      20.14
#
#    haemoglobin_level  blood_glucose_level  is_diabetic
# 0                6.6                  140            0
# 1                6.6                   80            0
# 2                5.7                  158            0
# 3                5.0                  155            0
# 4                4.8                  155            0

# %%
sns.scatterplot(data = data, x = "blood_glucose_level", y = "is_diabetic")
plt.title("Relation between blood_glucose_level and is_diabetic")
# Out:
# Text(0.5, 1.0, 'Relation between blood_glucose_level and is_diabetic')

# %% [markdown]
# 💡Insight: People having diabetes have glucose level beyond 125. But that is not the only factor in causing diabetes.
#     There are people who have glucose level between 125 and 200 don't have diabetes. There might be other factors contributing to this situation.

# %%
sns.scatterplot(data = data, x = "haemoglobin_level", y = "is_diabetic")
# Out:
# <Axes: xlabel='haemoglobin_level', ylabel='is_diabetic'>

# %% [markdown]
# 💡Insight: People having diabetes have haemoglobin_level beyond 5.5. But that is not the only factor in causing diabetes.
#     There are people who have haemoglobin_level between 5.5 and 6.5 don't have diabetes. There might be other factors contributing to this situation.

# %%
sns.scatterplot(data = data, x = "bmi_score", y = "is_diabetic")
# Out:
# <Axes: xlabel='bmi_score', ylabel='is_diabetic'>

# %% [markdown]
# 💡Insight: Looking at graph, its hard to say how bmi_score affects in causing diabetes.

# %%
data.bmi_score.corr(data.is_diabetic)
# Out:
# 0.21435740579951063
